# %% [markdown]
# ### [Kaggle Clone Coding] Home Credit Default Risk
# - [Home Credit Default Risk](https://www.kaggle.com/c/home-credit-default-risk)
# - [Stacking Test-Sklearn, XGBoost, CatBoost, LightGBM](https://www.kaggle.com/eliotbarr/stacking-test-sklearn-xgboost-catboost-lightgbm)
# <br>
# - Task : Supervised Binary Classification
#     - 0 : 대출 상환 O
#     - 1 : 대출 상환 X
#
# - CSV File
#     - application_{train|test}.csv
#     - bureau.csv : 모든 고객의 이전 credit
#     - bureau_balance.csv : 모든 고객의 이전 credit의 월별 잔액
#     - POS_CASH_balance.csv : 신청자가 home credit으로 가지고 있던 이전 pos(판매 시점)과 현금 대출의 월별 잔액
#     - credit_card_balance.csv : 신청자가 home credit으로 가지고 있던 이전 신용카드의 월별 잔액
#     - previous_application.csv : 고객의 주택신용대출에 대한 이전 모든 신청
#     - installments_payments.csv : 이전 home credit에 대한 상환 내역
#     - HomeCredit_columns_description.csv : 데이터 변수 설명

# %%
import pandas as pd
import numpy as np
from scipy.stats import skew
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LogisticRegression
from math import sqrt
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import KFold
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
import gc

NFOLDS = 3
SEED = 0
NROWS = None

data = pd.read_csv('./Home_Credit_Default_Risk/application_train.csv')
test = pd.read_csv('./Home_Credit_Default_Risk/application_test.csv')
prev = pd.read_csv('./Home_Credit_Default_Risk/previous_application.csv')

# %%
categorical_feats = [
    f for f in data.columns if data[f].dtype == 'object'
]

for f_ in categorical_feats:
    data[f_], indexer = pd.factorize(data[f_])
    test[f_] = indexer.get_indexer(test[f_])
    
gc.enable()
y_train = data['TARGET']
del data['TARGET']

# %%
prev_cat_features = [
    f_ for f_ in prev.columns if prev[f_].dtype == 'object'
]
for f_ in prev_cat_features:
    prev[f_], _ = pd.factorize(prev[f_])
    
avg_prev = prev.groupby('SK_ID_CURR').mean()
cnt_prev = prev[['SK_ID_CURR', 'SK_ID_PREV']].groupby('SK_ID_CURR').count()
avg_prev['nb_app'] = cnt_prev['SK_ID_PREV']
del avg_prev['SK_ID_PREV']

# %%
x_train = data.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')
x_test = test.merge(right=avg_prev.reset_index(), how='left', on='SK_ID_CURR')

x_train = x_train.fillna(0)
x_test= x_test.fillna(0)

ntrain = x_train.shape[0]
ntest = x_test.shape[0]

# %%
excluded_feats = ['SK_ID_CURR']
features = [f_ for f_ in x_train.columns if f_ not in excluded_feats]

x_train = x_train[features]
x_test = x_test[features]

kf = KFold(n_splits = NFOLDS, shuffle=True, random_state=SEED)

# %%
class SklearnWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_state'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]

class CatboostWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['random_seed'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]
        
class LightGBMWrapper(object):
    def __init__(self, clf, seed=0, params=None):
        params['feature_fraction_seed'] = seed
        params['bagging_seed'] = seed
        self.clf = clf(**params)

    def train(self, x_train, y_train):
        self.clf.fit(x_train, y_train)

    def predict(self, x):
        return self.clf.predict_proba(x)[:,1]


class XgbWrapper(object):
    def __init__(self, seed=0, params=None):
        self.param = params
        self.param['seed'] = seed
        self.nrounds = params.pop('nrounds', 250)

    def train(self, x_train, y_train):
        dtrain = xgb.DMatrix(x_train, label=y_train)
        self.gbdt = xgb.train(self.param, dtrain, self.nrounds)

    def predict(self, x):
        return self.gbdt.predict(xgb.DMatrix(x))

# %%
def get_oof(clf):
    oof_train = np.zeros((ntrain,))
    oof_test = np.zeros((ntest,))
    oof_test_skf = np.empty((NFOLDS, ntest))

    for i, (train_index, test_index) in enumerate(kf.split(x_train)):
        x_tr = x_train.loc[train_index]
        y_tr = y_train.loc[train_index]
        x_te = x_train.loc[test_index]

        clf.train(x_tr, y_tr)

        oof_train[test_index] = clf.predict(x_te)
        oof_test_skf[i, :] = clf.predict(x_test)

    oof_test[:] = oof_test_skf.mean(axis=0)
    return oof_train.reshape(-1, 1), oof_test.reshape(-1, 1)

# %%
et_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.5,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

rf_params = {
    'n_jobs': 16,
    'n_estimators': 200,
    'max_features': 0.2,
    'max_depth': 12,
    'min_samples_leaf': 2,
}

xgb_params = {
    'seed': 0,
    'colsample_bytree': 0.7,
    'silent': 1,
    'subsample': 0.7,
    'learning_rate': 0.075,
    'objective': 'binary:logistic',
    'max_depth': 4,
    'num_parallel_tree': 1,
    'min_child_weight': 1,
    'nrounds': 200
}

catboost_params = {
    'iterations': 200,
    'learning_rate': 0.5,
    'depth': 3,
    'l2_leaf_reg': 40,
    'bootstrap_type': 'Bernoulli',
    'subsample': 0.7,
    'scale_pos_weight': 5,
    'eval_metric': 'AUC',
    'od_type': 'Iter',
    'allow_writing_files': False
}

lightgbm_params = {
    'n_estimators':200,
    'learning_rate':0.1,
    'num_leaves':123,
    'colsample_bytree':0.8,
    'subsample':0.9,
    'max_depth':15,
    'reg_alpha':0.1,
    'reg_lambda':0.1,
    'min_split_gain':0.01,
    'min_child_weight':2    
}

# %%
xg = XgbWrapper(seed=SEED, params=xgb_params)
et = SklearnWrapper(clf=ExtraTreesClassifier, seed=SEED, params=et_params)
rf = SklearnWrapper(clf=RandomForestClassifier, seed=SEED, params=rf_params)
cb = CatboostWrapper(clf= CatBoostClassifier, seed = SEED, params=catboost_params)
lg = LightGBMWrapper(clf = LGBMClassifier, seed = SEED, params = lightgbm_params)

xg_oof_train, xg_oof_test = get_oof(xg)
et_oof_train, et_oof_test = get_oof(et)
rf_oof_train, rf_oof_test = get_oof(rf)
cb_oof_train, cb_oof_test = get_oof(cb)
# Out:
# [16:36:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:36:11] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:36:52] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:36:53] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [16:37:35] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:541:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [16:37:36] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# 0:	total: 215ms	remaining: 42.7s
# 1:	total: 261ms	remaining: 25.8s
# 2:	total: 298ms	remaining: 19.6s
# 3:	total: 338ms	remaining: 16.6s
# 4:	total: 377ms	remaining: 14.7s
# 5:	total: 424ms	remaining: 13.7s
# 6:	total: 461ms	remaining: 12.7s
# 7:	total: 498ms	remaining: 11.9s
# 8:	total: 537ms	remaining: 11.4s
# 9:	total: 578ms	remaining: 11s
# 10:	total: 616ms	remaining: 10.6s
# 11:	total: 661ms	remaining: 10.4s
# 12:	total: 701ms	remaining: 10.1s
# 13:	total: 739ms	remaining: 9.82s
# 14:	total: 778ms	remaining: 9.59s
# 15:	total: 821ms	remaining: 9.44s
# 16:	total: 856ms	remaining: 9.21s
# 17:	total: 891ms	remaining: 9.01s
# 18:	total: 928ms	remaining: 8.84s
# 19:	total: 965ms	remaining: 8.68s
# 20:	total: 1s	remaining: 8.53s
# 21:	total: 1.04s	remaining: 8.45s
# 22:	total: 1.08s	remaining: 8.35s
# 23:	total: 1.13s	remaining: 8.28s
# 24:	total: 1.17s	remaining: 8.19s
# 25:	total: 1.21s	remaining: 8.1s
# 26:	total: 1.25s	remaining: 8s
# 27:	total: 1.29s	remaining: 7.91s
# 28:	total: 1.33s	remaining: 7.83s
# 29:	total: 1.36s	remaining: 7.73s
# 30:	total: 1.4s	remaining: 7.63s
# 31:	total: 1.44s	remaining: 7.58s
# 32:	total: 1.49s	remaining: 7.51s
# 33:	total: 1.53s	remaining: 7.46s
# 34:	total: 1.57s	remaining: 7.39s
# 35:	total: 1.6s	remaining: 7.31s
# 36:	total: 1.64s	remaining: 7.24s
# 37:	total: 1.69s	remaining: 7.19s
# 38:	total: 1.73s	remaining: 7.13s
# 39:	total: 1.77s	remaining: 7.07s
# 40:	total: 1.81s	remaining: 7.01s
# 41:	total: 1.85s	remaining: 6.96s
# 42:	total: 1.89s	remaining: 6.91s
# 43:	total: 1.94s	remaining: 6.86s
# 44:	total: 1.98s	remaining: 6.8s
# 45:	total: 2.02s	remaining: 6.75s
# 46:	total: 2.06s	remaining: 6.69s
# 47:	total: 2.09s	remaining: 6.63s
# 48:	total: 2.13s	remaining: 6.56s
# 49:	total: 2.17s	remaining: 6.51s
# 50:	total: 2.21s	remaining: 6.44s
# 51:	total: 2.24s	remaining: 6.38s
# 52:	total: 2.29s	remaining: 6.34s
# 53:	total: 2.32s	remaining: 6.28s
# 54:	total: 2.37s	remaining: 6.24s
# 55:	total: 2.41s	remaining: 6.19s
# 56:	total: 2.45s	remaining: 6.14s
# 57:	total: 2.49s	remaining: 6.1s
# 58:	total: 2.53s	remaining: 6.05s
# 59:	total: 2.57s	remaining: 6s
# 60:	total: 2.61s	remaining: 5.94s
# 61:	total: 2.65s	remaining: 5.9s
# 62:	total: 2.69s	remaining: 5.86s
# 63:	total: 2.73s	remaining: 5.81s
# 64:	total: 2.77s	remaining: 5.75s
# 65:	total: 2.81s	remaining: 5.7s
# 66:	total: 2.85s	remaining: 5.65s
# 67:	total: 2.9s	remaining: 5.62s
# 68:	total: 2.94s	remaining: 5.58s
# 69:	total: 2.98s	remaining: 5.54s
# 70:	total: 3.02s	remaining: 5.49s
# 71:	total: 3.06s	remaining: 5.44s
# 72:	total: 3.1s	remaining: 5.4s
# 73:	total: 3.14s	remaining: 5.35s
# 74:	total: 3.18s	remaining: 5.3s
# 75:	total: 3.22s	remaining: 5.25s
# 76:	total: 3.26s	remaining: 5.21s
# 77:	total: 3.3s	remaining: 5.17s
# 78:	total: 3.35s	remaining: 5.13s
# 79:	total: 3.39s	remaining: 5.08s
# 80:	total: 3.43s	remaining: 5.04s
# 81:	total: 3.47s	remaining: 4.99s
# 82:	total: 3.52s	remaining: 4.96s
# 83:	total: 3.56s	remaining: 4.91s
# 84:	total: 3.6s	remaining: 4.87s
# 85:	total: 3.64s	remaining: 4.82s
# 86:	total: 3.68s	remaining: 4.78s
# 87:	total: 3.72s	remaining: 4.73s
# 88:	total: 3.76s	remaining: 4.69s
# 89:	total: 3.8s	remaining: 4.64s
# 90:	total: 3.84s	remaining: 4.59s
# 91:	total: 3.88s	remaining: 4.56s
# 92:	total: 3.92s	remaining: 4.51s
# 93:	total: 3.96s	remaining: 4.46s
# 94:	total: 4s	remaining: 4.42s
# 95:	total: 4.04s	remaining: 4.38s
# 96:	total: 4.09s	remaining: 4.34s
# 97:	total: 4.13s	remaining: 4.3s
# 98:	total: 4.17s	remaining: 4.26s
# 99:	total: 4.21s	remaining: 4.21s
# 100:	total: 4.25s	remaining: 4.17s
# 101:	total: 4.3s	remaining: 4.13s
# 102:	total: 4.35s	remaining: 4.1s
# 103:	total: 4.39s	remaining: 4.05s
# 104:	total: 4.44s	remaining: 4.01s
# 105:	total: 4.48s	remaining: 3.97s
# 106:	total: 4.53s	remaining: 3.94s
# 107:	total: 4.57s	remaining: 3.89s
# 108:	total: 4.6s	remaining: 3.84s
# 109:	total: 4.64s	remaining: 3.8s
# 110:	total: 4.68s	remaining: 3.75s
# 111:	total: 4.72s	remaining: 3.71s
# 112:	total: 4.76s	remaining: 3.66s
# 113:	total: 4.79s	remaining: 3.62s
# 114:	total: 4.83s	remaining: 3.57s
# 115:	total: 4.87s	remaining: 3.53s
# 116:	total: 4.91s	remaining: 3.48s
# 117:	total: 4.95s	remaining: 3.44s
# 118:	total: 4.99s	remaining: 3.4s
# 119:	total: 5.03s	remaining: 3.35s
# 120:	total: 5.07s	remaining: 3.31s
# 121:	total: 5.11s	remaining: 3.26s
# 122:	total: 5.15s	remaining: 3.22s
# 123:	total: 5.19s	remaining: 3.18s
# 124:	total: 5.23s	remaining: 3.14s
# 125:	total: 5.28s	remaining: 3.1s
# 126:	total: 5.32s	remaining: 3.06s
# 127:	total: 5.36s	remaining: 3.02s
# 128:	total: 5.41s	remaining: 2.98s
# 129:	total: 5.45s	remaining: 2.94s
# 130:	total: 5.49s	remaining: 2.89s
# 131:	total: 5.54s	remaining: 2.85s
# 132:	total: 5.58s	remaining: 2.81s
# 133:	total: 5.64s	remaining: 2.78s
# 134:	total: 5.69s	remaining: 2.74s
# 135:	total: 5.74s	remaining: 2.7s
# 136:	total: 5.78s	remaining: 2.66s
# 137:	total: 5.82s	remaining: 2.62s
# 138:	total: 5.87s	remaining: 2.57s
# 139:	total: 5.91s	remaining: 2.53s
# 140:	total: 5.95s	remaining: 2.49s
# 141:	total: 5.99s	remaining: 2.44s
# 142:	total: 6.03s	remaining: 2.4s
# 143:	total: 6.06s	remaining: 2.36s
# 144:	total: 6.1s	remaining: 2.31s
# 145:	total: 6.14s	remaining: 2.27s
# 146:	total: 6.18s	remaining: 2.23s
# 147:	total: 6.21s	remaining: 2.18s
# 148:	total: 6.25s	remaining: 2.14s
# 149:	total: 6.3s	remaining: 2.1s
# 150:	total: 6.35s	remaining: 2.06s
# 151:	total: 6.39s	remaining: 2.02s
# 152:	total: 6.43s	remaining: 1.98s
# 153:	total: 6.48s	remaining: 1.93s
# 154:	total: 6.52s	remaining: 1.89s
# 155:	total: 6.57s	remaining: 1.85s
# 156:	total: 6.61s	remaining: 1.81s
# 157:	total: 6.65s	remaining: 1.77s
# 158:	total: 6.68s	remaining: 1.72s
# 159:	total: 6.72s	remaining: 1.68s
# 160:	total: 6.76s	remaining: 1.64s
# 161:	total: 6.8s	remaining: 1.59s
# 162:	total: 6.84s	remaining: 1.55s
# 163:	total: 6.87s	remaining: 1.51s
# 164:	total: 6.91s	remaining: 1.47s
# 165:	total: 6.96s	remaining: 1.43s
# 166:	total: 7s	remaining: 1.38s
# 167:	total: 7.04s	remaining: 1.34s
# 168:	total: 7.09s	remaining: 1.3s
# 169:	total: 7.13s	remaining: 1.26s
# 170:	total: 7.17s	remaining: 1.22s
# 171:	total: 7.21s	remaining: 1.17s
# 172:	total: 7.25s	remaining: 1.13s
# 173:	total: 7.29s	remaining: 1.09s
# 174:	total: 7.34s	remaining: 1.05s
# 175:	total: 7.39s	remaining: 1.01s
# 176:	total: 7.43s	remaining: 966ms
# 177:	total: 7.48s	remaining: 924ms
# 178:	total: 7.53s	remaining: 883ms
# 179:	total: 7.57s	remaining: 841ms
# 180:	total: 7.61s	remaining: 799ms
# 181:	total: 7.66s	remaining: 757ms
# 182:	total: 7.7s	remaining: 715ms
# 183:	total: 7.75s	remaining: 674ms
# 184:	total: 7.8s	remaining: 632ms
# 185:	total: 7.84s	remaining: 590ms
# 186:	total: 7.88s	remaining: 548ms
# 187:	total: 7.92s	remaining: 506ms
# 188:	total: 7.96s	remaining: 463ms
# 189:	total: 7.99s	remaining: 421ms
# 190:	total: 8.03s	remaining: 378ms
# 191:	total: 8.07s	remaining: 336ms
# 192:	total: 8.12s	remaining: 295ms
# 193:	total: 8.16s	remaining: 252ms
# 194:	total: 8.2s	remaining: 210ms
# 195:	total: 8.24s	remaining: 168ms
# 196:	total: 8.28s	remaining: 126ms
# 197:	total: 8.32s	remaining: 84ms
# 198:	total: 8.36s	remaining: 42ms
# 199:	total: 8.4s	remaining: 0us
# 0:	total: 41.9ms	remaining: 8.33s
# 1:	total: 83.3ms	remaining: 8.25s
# 2:	total: 125ms	remaining: 8.18s
# 3:	total: 169ms	remaining: 8.27s
# 4:	total: 212ms	remaining: 8.26s
# 5:	total: 259ms	remaining: 8.39s
# 6:	total: 303ms	remaining: 8.36s
# 7:	total: 340ms	remaining: 8.16s
# 8:	total: 380ms	remaining: 8.07s
# 9:	total: 420ms	remaining: 7.98s
# 10:	total: 458ms	remaining: 7.88s
# 11:	total: 502ms	remaining: 7.87s
# 12:	total: 546ms	remaining: 7.86s
# 13:	total: 594ms	remaining: 7.89s
# 14:	total: 633ms	remaining: 7.81s
# 15:	total: 676ms	remaining: 7.77s
# 16:	total: 722ms	remaining: 7.77s
# 17:	total: 766ms	remaining: 7.75s
# 18:	total: 809ms	remaining: 7.71s
# 19:	total: 851ms	remaining: 7.66s
# 20:	total: 894ms	remaining: 7.62s
# 21:	total: 939ms	remaining: 7.59s
# 22:	total: 989ms	remaining: 7.61s
# 23:	total: 1.02s	remaining: 7.52s
# 24:	total: 1.06s	remaining: 7.45s
# 25:	total: 1.11s	remaining: 7.43s
# 26:	total: 1.15s	remaining: 7.38s
# 27:	total: 1.2s	remaining: 7.34s
# 28:	total: 1.23s	remaining: 7.27s
# 29:	total: 1.27s	remaining: 7.19s
# 30:	total: 1.3s	remaining: 7.11s
# 31:	total: 1.34s	remaining: 7.07s
# 32:	total: 1.38s	remaining: 7s
# 33:	total: 1.42s	remaining: 6.92s
# 34:	total: 1.45s	remaining: 6.85s
# 35:	total: 1.49s	remaining: 6.8s
# 36:	total: 1.54s	remaining: 6.78s
# 37:	total: 1.58s	remaining: 6.72s
# 38:	total: 1.62s	remaining: 6.67s
# 39:	total: 1.65s	remaining: 6.62s
# 40:	total: 1.69s	remaining: 6.57s
# 41:	total: 1.73s	remaining: 6.52s
# 42:	total: 1.77s	remaining: 6.46s
# 43:	total: 1.81s	remaining: 6.42s
# 44:	total: 1.85s	remaining: 6.37s
# 45:	total: 1.89s	remaining: 6.34s
# 46:	total: 1.94s	remaining: 6.3s
# 47:	total: 1.98s	remaining: 6.25s
# 48:	total: 2.01s	remaining: 6.2s
# 49:	total: 2.05s	remaining: 6.15s
# 50:	total: 2.09s	remaining: 6.11s
# 51:	total: 2.13s	remaining: 6.07s
# 52:	total: 2.17s	remaining: 6.03s
# 53:	total: 2.21s	remaining: 5.98s
# 54:	total: 2.25s	remaining: 5.94s
# 55:	total: 2.29s	remaining: 5.9s
# 56:	total: 2.33s	remaining: 5.86s
# 57:	total: 2.38s	remaining: 5.82s
# 58:	total: 2.42s	remaining: 5.77s
# 59:	total: 2.45s	remaining: 5.72s
# 60:	total: 2.49s	remaining: 5.68s
# 61:	total: 2.53s	remaining: 5.63s
# 62:	total: 2.56s	remaining: 5.58s
# 63:	total: 2.6s	remaining: 5.54s
# 64:	total: 2.65s	remaining: 5.5s
# 65:	total: 2.69s	remaining: 5.46s
# 66:	total: 2.73s	remaining: 5.42s
# 67:	total: 2.77s	remaining: 5.37s
# 68:	total: 2.8s	remaining: 5.32s
# 69:	total: 2.85s	remaining: 5.28s
# 70:	total: 2.88s	remaining: 5.24s
# 71:	total: 2.92s	remaining: 5.2s
# 72:	total: 2.96s	remaining: 5.16s
# 73:	total: 3s	remaining: 5.11s
# 74:	total: 3.04s	remaining: 5.07s
# 75:	total: 3.08s	remaining: 5.03s
# 76:	total: 3.13s	remaining: 4.99s
# 77:	total: 3.16s	remaining: 4.95s
# 78:	total: 3.21s	remaining: 4.91s
# 79:	total: 3.25s	remaining: 4.87s
# 80:	total: 3.29s	remaining: 4.83s
# 81:	total: 3.32s	remaining: 4.78s
# 82:	total: 3.36s	remaining: 4.74s
# 83:	total: 3.41s	remaining: 4.71s
# 84:	total: 3.45s	remaining: 4.67s
# 85:	total: 3.49s	remaining: 4.62s
# 86:	total: 3.53s	remaining: 4.58s
# 87:	total: 3.57s	remaining: 4.55s
# 88:	total: 3.61s	remaining: 4.5s
# 89:	total: 3.65s	remaining: 4.46s
# 90:	total: 3.69s	remaining: 4.42s
# 91:	total: 3.73s	remaining: 4.38s
# 92:	total: 3.77s	remaining: 4.34s
# 93:	total: 3.82s	remaining: 4.3s
# 94:	total: 3.86s	remaining: 4.26s
# 95:	total: 3.9s	remaining: 4.22s
# 96:	total: 3.93s	remaining: 4.18s
# 97:	total: 3.97s	remaining: 4.13s
# 98:	total: 4.01s	remaining: 4.09s
# 99:	total: 4.05s	remaining: 4.05s
# 100:	total: 4.09s	remaining: 4.01s
# 101:	total: 4.14s	remaining: 3.98s
# 102:	total: 4.17s	remaining: 3.93s
# 103:	total: 4.21s	remaining: 3.89s
# 104:	total: 4.26s	remaining: 3.85s
# 105:	total: 4.3s	remaining: 3.81s
# 106:	total: 4.34s	remaining: 3.77s
# 107:	total: 4.38s	remaining: 3.73s
# 108:	total: 4.42s	remaining: 3.69s
# 109:	total: 4.46s	remaining: 3.65s
# 110:	total: 4.5s	remaining: 3.61s
# 111:	total: 4.54s	remaining: 3.56s
# 112:	total: 4.58s	remaining: 3.52s
# 113:	total: 4.61s	remaining: 3.48s
# 114:	total: 4.66s	remaining: 3.44s
# 115:	total: 4.69s	remaining: 3.4s
# 116:	total: 4.73s	remaining: 3.36s
# 117:	total: 4.78s	remaining: 3.32s
# 118:	total: 4.81s	remaining: 3.27s
# 119:	total: 4.85s	remaining: 3.23s
# 120:	total: 4.89s	remaining: 3.19s
# 121:	total: 4.94s	remaining: 3.16s
# 122:	total: 4.99s	remaining: 3.12s
# 123:	total: 5.03s	remaining: 3.08s
# 124:	total: 5.06s	remaining: 3.04s
# 125:	total: 5.1s	remaining: 3s
# 126:	total: 5.15s	remaining: 2.96s
# 127:	total: 5.19s	remaining: 2.92s
# 128:	total: 5.23s	remaining: 2.88s
# 129:	total: 5.27s	remaining: 2.84s
# 130:	total: 5.31s	remaining: 2.79s
# 131:	total: 5.34s	remaining: 2.75s
# 132:	total: 5.38s	remaining: 2.71s
# 133:	total: 5.41s	remaining: 2.67s
# 134:	total: 5.45s	remaining: 2.62s
# 135:	total: 5.48s	remaining: 2.58s
# 136:	total: 5.52s	remaining: 2.54s
# 137:	total: 5.56s	remaining: 2.5s
# 138:	total: 5.6s	remaining: 2.46s
# 139:	total: 5.64s	remaining: 2.42s
# 140:	total: 5.67s	remaining: 2.37s
# 141:	total: 5.72s	remaining: 2.33s
# 142:	total: 5.76s	remaining: 2.29s
# 143:	total: 5.8s	remaining: 2.25s
# 144:	total: 5.83s	remaining: 2.21s
# 145:	total: 5.88s	remaining: 2.17s
# 146:	total: 5.94s	remaining: 2.14s
# 147:	total: 5.99s	remaining: 2.1s
# 148:	total: 6.04s	remaining: 2.06s
# 149:	total: 6.08s	remaining: 2.02s
# 150:	total: 6.12s	remaining: 1.98s
# 151:	total: 6.15s	remaining: 1.94s
# 152:	total: 6.2s	remaining: 1.9s
# 153:	total: 6.24s	remaining: 1.86s
# 154:	total: 6.28s	remaining: 1.82s
# 155:	total: 6.32s	remaining: 1.78s
# 156:	total: 6.36s	remaining: 1.74s
# 157:	total: 6.41s	remaining: 1.7s
# 158:	total: 6.44s	remaining: 1.66s
# 159:	total: 6.48s	remaining: 1.62s
# 160:	total: 6.52s	remaining: 1.58s
# 161:	total: 6.56s	remaining: 1.54s
# 162:	total: 6.6s	remaining: 1.5s
# 163:	total: 6.64s	remaining: 1.46s
# 164:	total: 6.68s	remaining: 1.42s
# 165:	total: 6.71s	remaining: 1.38s
# 166:	total: 6.75s	remaining: 1.33s
# 167:	total: 6.79s	remaining: 1.29s
# 168:	total: 6.83s	remaining: 1.25s
# 169:	total: 6.87s	remaining: 1.21s
# 170:	total: 6.91s	remaining: 1.17s
# 171:	total: 6.94s	remaining: 1.13s
# 172:	total: 6.98s	remaining: 1.09s
# 173:	total: 7.03s	remaining: 1.05s
# 174:	total: 7.07s	remaining: 1.01s
# 175:	total: 7.11s	remaining: 969ms
# 176:	total: 7.15s	remaining: 929ms
# 177:	total: 7.19s	remaining: 889ms
# 178:	total: 7.23s	remaining: 849ms
# 179:	total: 7.27s	remaining: 808ms
# 180:	total: 7.31s	remaining: 767ms
# 181:	total: 7.35s	remaining: 727ms
# 182:	total: 7.39s	remaining: 687ms
# 183:	total: 7.43s	remaining: 646ms
# 184:	total: 7.46s	remaining: 605ms
# 185:	total: 7.5s	remaining: 565ms
# 186:	total: 7.54s	remaining: 524ms
# 187:	total: 7.58s	remaining: 484ms
# 188:	total: 7.62s	remaining: 443ms
# 189:	total: 7.66s	remaining: 403ms
# 190:	total: 7.7s	remaining: 363ms
# 191:	total: 7.73s	remaining: 322ms
# 192:	total: 7.78s	remaining: 282ms
# 193:	total: 7.82s	remaining: 242ms
# 194:	total: 7.85s	remaining: 201ms
# 195:	total: 7.89s	remaining: 161ms
# 196:	total: 7.93s	remaining: 121ms
# 197:	total: 7.97s	remaining: 80.5ms
# 198:	total: 8.01s	remaining: 40.2ms
# 199:	total: 8.05s	remaining: 0us
# 0:	total: 45.3ms	remaining: 9.02s
# 1:	total: 88ms	remaining: 8.71s
# 2:	total: 132ms	remaining: 8.69s
# 3:	total: 174ms	remaining: 8.52s
# 4:	total: 216ms	remaining: 8.44s
# 5:	total: 260ms	remaining: 8.39s
# 6:	total: 302ms	remaining: 8.34s
# 7:	total: 347ms	remaining: 8.33s
# 8:	total: 392ms	remaining: 8.33s
# 9:	total: 433ms	remaining: 8.22s
# 10:	total: 478ms	remaining: 8.22s
# 11:	total: 519ms	remaining: 8.13s
# 12:	total: 559ms	remaining: 8.03s
# 13:	total: 599ms	remaining: 7.95s
# 14:	total: 639ms	remaining: 7.88s
# 15:	total: 679ms	remaining: 7.81s
# 16:	total: 725ms	remaining: 7.81s
# 17:	total: 765ms	remaining: 7.74s
# 18:	total: 800ms	remaining: 7.62s
# 19:	total: 839ms	remaining: 7.55s
# 20:	total: 882ms	remaining: 7.51s
# 21:	total: 930ms	remaining: 7.53s
# 22:	total: 970ms	remaining: 7.46s
# 23:	total: 1.01s	remaining: 7.44s
# 24:	total: 1.05s	remaining: 7.39s
# 25:	total: 1.09s	remaining: 7.33s
# 26:	total: 1.13s	remaining: 7.25s
# 27:	total: 1.17s	remaining: 7.19s
# 28:	total: 1.21s	remaining: 7.14s
# 29:	total: 1.25s	remaining: 7.1s
# 30:	total: 1.29s	remaining: 7.06s
# 31:	total: 1.33s	remaining: 6.99s
# 32:	total: 1.37s	remaining: 6.92s
# 33:	total: 1.41s	remaining: 6.87s
# 34:	total: 1.45s	remaining: 6.83s
# 35:	total: 1.49s	remaining: 6.8s
# 36:	total: 1.54s	remaining: 6.78s
# 37:	total: 1.58s	remaining: 6.72s
# 38:	total: 1.62s	remaining: 6.67s
# 39:	total: 1.65s	remaining: 6.62s
# 40:	total: 1.7s	remaining: 6.59s
# 41:	total: 1.73s	remaining: 6.53s
# 42:	total: 1.77s	remaining: 6.48s
# 43:	total: 1.81s	remaining: 6.43s
# 44:	total: 1.85s	remaining: 6.36s
# 45:	total: 1.89s	remaining: 6.32s
# 46:	total: 1.93s	remaining: 6.28s
# 47:	total: 1.98s	remaining: 6.25s
# 48:	total: 2.02s	remaining: 6.21s
# 49:	total: 2.06s	remaining: 6.18s
# 50:	total: 2.1s	remaining: 6.15s
# 51:	total: 2.15s	remaining: 6.12s
# 52:	total: 2.2s	remaining: 6.1s
# 53:	total: 2.25s	remaining: 6.07s
# 54:	total: 2.29s	remaining: 6.03s
# 55:	total: 2.32s	remaining: 5.97s
# 56:	total: 2.36s	remaining: 5.91s
# 57:	total: 2.39s	remaining: 5.86s
# 58:	total: 2.43s	remaining: 5.81s
# 59:	total: 2.47s	remaining: 5.76s
# 60:	total: 2.5s	remaining: 5.71s
# 61:	total: 2.54s	remaining: 5.65s
# 62:	total: 2.57s	remaining: 5.6s
# 63:	total: 2.61s	remaining: 5.55s
# 64:	total: 2.65s	remaining: 5.5s
# 65:	total: 2.69s	remaining: 5.45s
# 66:	total: 2.72s	remaining: 5.4s
# 67:	total: 2.76s	remaining: 5.36s
# 68:	total: 2.79s	remaining: 5.3s
# 69:	total: 2.83s	remaining: 5.25s
# 70:	total: 2.86s	remaining: 5.2s
# 71:	total: 2.9s	remaining: 5.16s
# 72:	total: 2.94s	remaining: 5.12s
# 73:	total: 2.98s	remaining: 5.07s
# 74:	total: 3.02s	remaining: 5.03s
# 75:	total: 3.05s	remaining: 4.98s
# 76:	total: 3.09s	remaining: 4.94s
# 77:	total: 3.13s	remaining: 4.9s
# 78:	total: 3.17s	remaining: 4.86s
# 79:	total: 3.21s	remaining: 4.82s
# 80:	total: 3.25s	remaining: 4.78s
# 81:	total: 3.29s	remaining: 4.73s
# 82:	total: 3.32s	remaining: 4.68s
# 83:	total: 3.36s	remaining: 4.63s
# 84:	total: 3.39s	remaining: 4.59s
# 85:	total: 3.43s	remaining: 4.55s
# 86:	total: 3.46s	remaining: 4.5s
# 87:	total: 3.5s	remaining: 4.46s
# 88:	total: 3.55s	remaining: 4.43s
# 89:	total: 3.59s	remaining: 4.38s
# 90:	total: 3.62s	remaining: 4.34s
# 91:	total: 3.66s	remaining: 4.3s
# 92:	total: 3.7s	remaining: 4.26s
# 93:	total: 3.74s	remaining: 4.22s
# 94:	total: 3.78s	remaining: 4.18s
# 95:	total: 3.82s	remaining: 4.13s
# 96:	total: 3.85s	remaining: 4.09s
# 97:	total: 3.89s	remaining: 4.05s
# 98:	total: 3.93s	remaining: 4s
# 99:	total: 3.96s	remaining: 3.96s
# 100:	total: 4s	remaining: 3.92s
# 101:	total: 4.03s	remaining: 3.87s
# 102:	total: 4.07s	remaining: 3.83s
# 103:	total: 4.1s	remaining: 3.79s
# 104:	total: 4.14s	remaining: 3.75s
# 105:	total: 4.18s	remaining: 3.71s
# 106:	total: 4.22s	remaining: 3.67s
# 107:	total: 4.27s	remaining: 3.64s
# 108:	total: 4.3s	remaining: 3.59s
# 109:	total: 4.35s	remaining: 3.56s
# 110:	total: 4.38s	remaining: 3.51s
# 111:	total: 4.42s	remaining: 3.47s
# 112:	total: 4.46s	remaining: 3.43s
# 113:	total: 4.49s	remaining: 3.39s
# 114:	total: 4.53s	remaining: 3.35s
# 115:	total: 4.57s	remaining: 3.31s
# 116:	total: 4.6s	remaining: 3.26s
# 117:	total: 4.64s	remaining: 3.23s
# 118:	total: 4.68s	remaining: 3.18s
# 119:	total: 4.71s	remaining: 3.14s
# 120:	total: 4.75s	remaining: 3.1s
# 121:	total: 4.78s	remaining: 3.06s
# 122:	total: 4.82s	remaining: 3.02s
# 123:	total: 4.86s	remaining: 2.98s
# 124:	total: 4.89s	remaining: 2.93s
# 125:	total: 4.93s	remaining: 2.89s
# 126:	total: 4.96s	remaining: 2.85s
# 127:	total: 5s	remaining: 2.81s
# 128:	total: 5.04s	remaining: 2.77s
# 129:	total: 5.09s	remaining: 2.74s
# 130:	total: 5.13s	remaining: 2.7s
# 131:	total: 5.17s	remaining: 2.66s
# 132:	total: 5.21s	remaining: 2.62s
# 133:	total: 5.25s	remaining: 2.59s
# 134:	total: 5.28s	remaining: 2.54s
# 135:	total: 5.32s	remaining: 2.5s
# 136:	total: 5.35s	remaining: 2.46s
# 137:	total: 5.39s	remaining: 2.42s
# 138:	total: 5.43s	remaining: 2.38s
# 139:	total: 5.46s	remaining: 2.34s
# 140:	total: 5.5s	remaining: 2.3s
# 141:	total: 5.54s	remaining: 2.26s
# 142:	total: 5.58s	remaining: 2.22s
# 143:	total: 5.63s	remaining: 2.19s
# 144:	total: 5.66s	remaining: 2.15s
# 145:	total: 5.69s	remaining: 2.11s
# 146:	total: 5.73s	remaining: 2.06s
# 147:	total: 5.76s	remaining: 2.02s
# 148:	total: 5.8s	remaining: 1.99s
# 149:	total: 5.84s	remaining: 1.95s
# 150:	total: 5.88s	remaining: 1.91s
# 151:	total: 5.91s	remaining: 1.86s
# 152:	total: 5.94s	remaining: 1.82s
# 153:	total: 5.97s	remaining: 1.78s
# 154:	total: 6.02s	remaining: 1.75s
# 155:	total: 6.05s	remaining: 1.71s
# 156:	total: 6.09s	remaining: 1.67s
# 157:	total: 6.12s	remaining: 1.63s
# 158:	total: 6.17s	remaining: 1.59s
# 159:	total: 6.21s	remaining: 1.55s
# 160:	total: 6.25s	remaining: 1.51s
# 161:	total: 6.29s	remaining: 1.47s
# 162:	total: 6.34s	remaining: 1.44s
# 163:	total: 6.4s	remaining: 1.41s
# 164:	total: 6.43s	remaining: 1.36s
# 165:	total: 6.47s	remaining: 1.32s
# 166:	total: 6.51s	remaining: 1.28s
# 167:	total: 6.54s	remaining: 1.25s
# 168:	total: 6.58s	remaining: 1.21s
# 169:	total: 6.61s	remaining: 1.17s
# 170:	total: 6.65s	remaining: 1.13s
# 171:	total: 6.69s	remaining: 1.09s
# 172:	total: 6.73s	remaining: 1.05s
# 173:	total: 6.76s	remaining: 1.01s
# 174:	total: 6.81s	remaining: 973ms
# 175:	total: 6.84s	remaining: 933ms
# 176:	total: 6.88s	remaining: 894ms
# 177:	total: 6.92s	remaining: 855ms
# 178:	total: 6.95s	remaining: 816ms
# 179:	total: 6.99s	remaining: 777ms
# 180:	total: 7.03s	remaining: 738ms
# 181:	total: 7.06s	remaining: 699ms
# 182:	total: 7.1s	remaining: 659ms
# 183:	total: 7.14s	remaining: 621ms
# 184:	total: 7.18s	remaining: 582ms
# 185:	total: 7.21s	remaining: 543ms
# 186:	total: 7.25s	remaining: 504ms
# 187:	total: 7.29s	remaining: 465ms
# 188:	total: 7.32s	remaining: 426ms
# 189:	total: 7.36s	remaining: 388ms
# 190:	total: 7.4s	remaining: 349ms
# 191:	total: 7.44s	remaining: 310ms
# 192:	total: 7.47s	remaining: 271ms
# 193:	total: 7.51s	remaining: 232ms
# 194:	total: 7.55s	remaining: 194ms
# 195:	total: 7.59s	remaining: 155ms
# 196:	total: 7.62s	remaining: 116ms
# 197:	total: 7.65s	remaining: 77.3ms
# 198:	total: 7.69s	remaining: 38.7ms
# 199:	total: 7.73s	remaining: 0us
# XG-CV: 0.25969546149690725
# ET-CV: 0.26296502347137407
# RF-CV: 0.2629856213006646
# RF-CV: 0.3309876006961808

# %%
print("XG-CV: {}".format(sqrt(mean_squared_error(y_train, xg_oof_train))))
print("ET-CV: {}".format(sqrt(mean_squared_error(y_train, et_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, rf_oof_train))))
print("RF-CV: {}".format(sqrt(mean_squared_error(y_train, cb_oof_train))))
# Out:
# XG-CV: 0.25969546149690725
# ET-CV: 0.26296502347137407
# RF-CV: 0.2629856213006646
# RF-CV: 0.3309876006961808

# %%
x_train = np.concatenate((xg_oof_train, et_oof_train, rf_oof_train, cb_oof_train), axis=1)
x_test = np.concatenate((xg_oof_test, et_oof_test, rf_oof_test, cb_oof_test), axis=1)

print("{},{}".format(x_train.shape, x_test.shape))
# Out:
# (307511, 4),(48744, 4)

# %%
logistic_regression = LogisticRegression()
logistic_regression.fit(x_train,y_train)

test['TARGET'] = logistic_regression.predict_proba(x_test)[:,1]

test[['SK_ID_CURR', 'TARGET']].to_csv('first_submission.csv', index=False, float_format='%.8f')
